# %%
"""
Create subword dictionary to breakdown words for embedding training
"""

import pickle
from collections import Counter
from tqdm import tqdm

import numpy as np
from matplotlib import pyplot as plt

# %%
#Load Assets
with open(r'D:\dstore\nlp\w2v\wcounts16', 'rt', encoding='utf8') as f:
    wlst = [x.strip().split() for x in f.readlines()]

with open(r'D:\dstore\nlp\w2v\prefs', 'rt', encoding='utf8') as f:
    subw = {x.strip() for x in f.readlines()}

with open(r'D:\dstore\nlp\w2v\suffs', 'rt', encoding='utf8') as f:
    for x in f.readlines():
        subw.add(x.strip())

for x in {'when_', 'been_', 'have_', 'two_', 'they_', 'who_', 'not_', 'new_', 'but_', 'her_', 'she_', 'after_', 'one_', 'their_', 'or_', 'has_', 'first_', 'had_', 'be_', 'also_', 'this_', 'are_', 'which_', 'were_', 'an_', 'it_', 'his_', 'from_', 'at_', 'that_', 'he_', 'by_', 'with_', 'as_', 'for_', 'on_', 'is_', 'was_', 'to_', 'and_', 'in_', 'of_', 'the_'}:
    subw.add(x)

#Filter out words w/ < 256 occurences 
wlst = Counter({x[1]: int(x[0]) for x in wlst if int(x[0]) > 256})

#Count letters in all words
lcount = Counter()
for x in wlst:
    for y in x:
        lcount[y] += 1

#Filter out letters w/ < 256 occurences
lcount = Counter({x[0]: x[1] for x in lcount.items() if x[1] >= 256})
alpha = [*lcount, '_', "'", '[UNK]']
wlst = {' '.join(list(x[0])): x[1] for x in wlst.items()}

#Remove all words with unknown letters
temp = []
for x in wlst:
    for y in x.split():
        if y not in alpha:
            temp.append(x)
            break
for x in temp:
    wlst.pop(x)

#Remove all words that do not have a vowel
vowels = ['a', 'e', 'i', 'o', 'u', 'y', 'á', 'é', 'ö']

wlst = Counter({f'_{x[0]}_': x[1] for x in wlst.items() if len(x[0]) > 1 and any({y for y in vowels if y in x[0]})})
wlst = Counter({''.join(x[0].split()): x[1] for x in wlst.items()})

ngrams = Counter()
for n in range(2, 9):
    for w in wlst:
        for i in range(0, len(w) - n + 1):
            ngrams[w[i:i+n]] += 1


wlst = Counter()
for x in ngrams.most_common():
    if x[1] >= 8:
        if len(x[0]) > 1:
            wlst[x[0]] += x[1]

def tree_split(input: list[tuple[str, int]], max_depth: int, depth:int=0):
    tree = []
    while input:
        trunk = input.pop(0)
        branches = []
        for x in input[::-1]:
            if trunk[0] in x[0]:
                branches.append(x)
                input.remove(x)
        tree.append((trunk, branches[::-1]))
    depth += 1
    if max_depth != depth:
        for i, split in enumerate(tree):
            tree[i] = (split[0], tree_split(split[1], max_depth, depth))
        tree = tree
    return tree

# %%
commons = wlst.most_common()

for i, x in tqdm(enumerate(commons)):
    for y in commons[i+1:]:
        if x[0] in y[0]:
            wlst[x[0]] -= wlst[y[0]]
            break
# Out:
# 54821it [01:41, 541.88it/s]

# %%
affixes = Counter({x[0]: x[1] for x in wlst.most_common() if '_' in x[0] and x[1] > 16 and len(x[0]) > 2})

# %%
[x for x in affixes.most_common() if 's_' in x[0]]

# %%
asplit = tree_split(affixes.most_common(), 6)

# %%
np.mean([x[0][1] for x in asplit])
# Out:
# 4236.660714285715

# %%
asplit
# Out:
# [(('ed_', 5127),
#   [(('ted_', 1271),
#     [(('ated_', 533),
#       [(('rated_', 100), [(('erated_', 35), []), (('orated_', 18), [])]),
#        (('lated_', 91), [(('ulated_', 44), [])]),
#        (('nated_', 61), [(('inated_', 36), [(('minated_', 18), [])])]),
#        (('cated_', 51), [(('icated_', 30), [])]),
#        (('iated_', 46), []),
#        (('tated_', 36), [(('itated_', 19), [])]),
#        (('gated_', 30), []),
#        (('eated_', 25), []),
#        (('dated_', 18), []),
#        (('uated_', 17), []),
#        (('mated_', 17), [])]),
#      (('nted_', 121),
#       [(('ented_', 56), [(('mented_', 24), [])]),
#        (('inted_', 26), []),
#        (('unted_', 20), []),
#        (('anted_', 17), [])]),
#      (('sted_', 116),
#       [(('ested_', 38), []), (('isted_', 23), []), (('asted_', 22), [])]),
#      (('cted_', 112), [(('ected_', 60), []), (('acted_', 24), [])]),
#      (('rted_', 68), [(('orted_', 28), []), (('erted_', 20), [])]),
#      (('ited_', 66), []),
#      (('tted_', 57), [(('itted_', 23), [])]),
#      (('eted_', 45), []),
#      (('uted_', 43), []),
#      (('pted_', 27), []),
#      (('lted_', 26), []),
#      (('oted_', 21), [])]),
#    (('red_', 494),
#     [(('ered_', 211),
#       [(('tered_', 63), [(('stered_', 19), []), (('ttered_', 18), [])]),
#        (('dered_', 32), [(('ndered_', 19), [])]),
#        (('hered_', 17), []),
#        (('vered_', 17), [])]),
#      (('ured_', 78), [(('tured_', 27), []), (('oured_', 21), [])]),
#      (('ored_', 56), []),
#      (('ired_', 39), []),
#      (('ared_', 38), []),
#      (('rred_', 35), [])]),
#    (('led_', 414),
#     [(('lled_', 103),
#       [(('elled_', 38), []), (('illed_', 24), []), (('alled_', 24), [])]),
#      (('iled_', 51), [(('ailed_', 22), [])]),
#      (('eled_', 36), []),
#      (('bled_', 36), []),
#      (('aled_', 29), []),
#      (('tled_', 27), []),
#      (('dled_', 20), []),
#      (('pled_', 17), [])]),
#    (('sed_', 394),
#     [(('ised_', 176),
#       [(('lised_', 58), [(('alised_', 43), [])]),
#        (('nised_', 24), []),
#        (('rised_', 24), [])]),
#      (('ssed_', 75), [(('essed_', 43), [(('ressed_', 25), [])])]),
#      (('osed_', 37), [(('posed_', 24), [])]),
#      (('used_', 35), []),
#      (('ased_', 30), [])]),
#    (('ned_', 360),
#     [(('ined_', 100), [(('ained_', 44), [])]),
#      (('oned_', 86), [(('ioned_', 50), [(('tioned_', 32), [])])]),
#      (('ened_', 63), [(('tened_', 21), [])]),
#      (('rned_', 30), []),
#      (('nned_', 28), []),
#      (('gned_', 21), [(('igned_', 20), [])])]),
#    (('ded_', 293),
#     [(('nded_', 94),
#       [(('ended_', 36), []),
#        (('unded_', 28), [(('ounded_', 23), [])]),
#        (('anded_', 19), [])]),
#      (('aded_', 45), []),
#      (('ided_', 31), []),
#      (('rded_', 30), [(('arded_', 19), [])]),
#      (('eded_', 21), []),
#      (('uded_', 21), []),
#      (('lded_', 19), [])]),
#    (('zed_', 256),
#     [(('ized_', 235),
#       [(('lized_', 93), [(('alized_', 71), [])]),
#        (('rized_', 39), []),
#        (('nized_', 38), []),
#        (('tized_', 19), [])])]),
#    (('hed_', 215),
#     [(('shed_', 98),
#       [(('ished_', 54), [(('nished_', 17), [])]), (('ashed_', 24), [])]),
#      (('ched_', 84),
#       [(('tched_', 30), []), (('nched_', 18), []), (('ached_', 18), [])])]),
#    (('ied_', 186),
#     [(('fied_', 78), [(('ified_', 72), [(('tified_', 22), [])])]),
#      (('ried_', 39), []),
#      (('lied_', 21), [])]),
#    (('ked_', 176),
#     [(('cked_', 72), [(('acked_', 22), []), (('ocked_', 19), [])]),
#      (('rked_', 22), []),
#      (('oked_', 22), []),
#      (('nked_', 19), []),
#      (('aked_', 19), [])]),
#    (('ged_', 168),
#     [(('aged_', 43), []),
#      (('nged_', 35), []),
#      (('gged_', 34), []),
#      (('dged_', 21), []),
#      (('rged_', 20), [])]),
#    (('ped_', 150),
#     [(('pped_', 65), [(('apped_', 23), []), (('ipped_', 22), [])]),
#      (('mped_', 25), []),
#      (('oped_', 20), [])]),
#    (('med_', 144),
#     [(('rmed_', 33), []),
#      (('amed_', 32), []),
#      (('mmed_', 21), []),
#      (('omed_', 18), [])]),
#    (('ced_', 120),
#     [(('nced_', 42), []), (('aced_', 27), []), (('iced_', 21), [])]),
#    (('ved_', 102),
#     [(('aved_', 23), []),
#      (('rved_', 18), []),
#      (('ived_', 18), []),
#      (('oved_', 17), [])]),
#    (('eed_', 69), []),
#    (('bed_', 69), [(('bbed_', 19), [])]),
#    (('yed_', 62), [(('ayed_', 29), [])]),
#    (('wed_', 61), [(('owed_', 36), [])]),
#    (('ued_', 37), []),
#    (('fed_', 29), []),
#    (('xed_', 28), [])]),
#  (('ng_', 5030),
#   [(('ing_', 4437),
#     [(('ting_', 953),
#       [(('ating_', 325),
#         [(('rating_', 61), [(('erating_', 22), [])]),
#          (('lating_', 49), [(('ulating_', 23), [])]),
#          (('nating_', 36), [(('inating_', 24), [])]),
#          (('cating_', 30), []),
#          (('tating_', 24), []),
#          (('eating_', 21), []),
#          (('gating_', 21), []),
#          (('iating_', 21), [])]),
#        (('nting_', 91),
#         [(('enting_', 35), []), (('unting_', 20), []), (('inting_', 18), [])]),
#        (('sting_', 87), [(('esting_', 24), []), (('asting_', 24), [])]),
#        (('cting_', 84), [(('ecting_', 39), []), (('acting_', 20), [])]),
#        (('tting_', 80), [(('itting_', 25), []), (('etting_', 19), [])]),
#        (('iting_', 57), []),
#        (('rting_', 51), [(('orting_', 21), [])]),
#        (('eting_', 33), []),
#        (('uting_', 33), []),
#        (('lting_', 25), []),
#        (('oting_', 24), []),
#        (('hting_', 23), [(('ghting_', 20), [(('ighting_', 20), [])])]),
#        (('pting_', 19), [])]),
#      (('ling_', 494),
#       [(('lling_', 124),
#         [(('elling_', 54), []), (('illing_', 28), []), (('alling_', 24), [])]),
#        (('iling_', 46), [(('ailing_', 23), [])]),
#        (('bling_', 38), [(('mbling_', 19), [])]),
#        (('eling_', 36), []),
#        (('aling_', 34), []),
#        (('tling_', 29), []),
#        (('dling_', 25), []),
#        (('rling_', 24), []),
#        (('gling_', 22), []),
#        (('kling_', 21), [])]),
#      (('ring_', 452),
#       [(('ering_', 213),
#         [(('tering_', 61), [(('ttering_', 20), [])]),
#          (('dering_', 31), [(('ndering_', 19), [])]),
#          (('eering_', 21), []),
#          (('hering_', 20), []),
#          (('vering_', 18), [])]),
#        (('uring_', 58), [(('turing_', 23), [])]),
#        (('aring_', 50), [(('earing_', 23), [])]),
#        (('oring_', 47), []),
#        (('iring_', 28), []),
#        (('rring_', 25), [])]),
#      (('ding_', 346),
#       [(('nding_', 104),
#         [(('ending_', 41), []), (('anding_', 23), []), (('unding_', 20), [])]),
#        (('ading_', 54), [(('eading_', 19), [])]),
#        (('lding_', 46), []),
#        (('rding_', 30), [(('arding_', 21), [])]),
#        (('iding_', 28), []),
#        (('eding_', 25), []),
#        (('dding_', 24), [])]),
#      (('ning_', 329),
#       [(('ining_', 81), [(('aining_', 30), [])]),
#        (('oning_', 67), [(('ioning_', 33), [(('tioning_', 22), [])])]),
#        (('ening_', 62), [(('tening_', 21), [])]),
#        (('nning_', 50), [(('inning_', 17), [])]),
#        (('rning_', 23), [])]),
#      (('sing_', 249),
#       [(('ising_', 77), []),
#        (('ssing_', 60), [(('essing_', 31), [])]),
#        (('using_', 27), []),
#        (('osing_', 26), []),
#        (('asing_', 25), [])]),
#      (('king_', 234),
#       [(('cking_', 67), [(('acking_', 23), []), (('ocking_', 18), [])]),
#        (('aking_', 59), [(('making_', 22), [])]),
#        (('nking_', 26), []),
#        (('rking_', 24), []),
#        (('oking_', 20), [])]),
#      (('hing_', 192),
#       [(('ching_', 79), [(('tching_', 27), []), (('aching_', 19), [])]),
#        (('shing_', 71), [(('ishing_', 36), []), (('ashing_', 19), [])]),
#        (('thing_', 30), [])]),
#      (('ping_', 166),
#       [(('pping_', 60), [(('apping_', 22), []), (('ipping_', 17), [])]),
#        (('oping_', 22), []),
#        (('eping_', 20), [(('eeping_', 19), [])]),
#        (('mping_', 19), [])]),
#      (('ming_', 144),
#       [(('rming_', 29), []),
#        (('aming_', 27), []),
#        (('mming_', 25), []),
#        (('oming_', 22), [])]),
#      (('ying_', 144),
#       [(('fying_', 43), [(('ifying_', 40), [])]),
#        (('aying_', 23), []),
#        (('lying_', 19), []),
#        (('rying_', 18), [])]),
#      (('ging_', 143),
#       [(('gging_', 35), []), (('nging_', 33), []), (('aging_', 30), [])]),
#      (('zing_', 134),
#       [(('izing_', 109),
#         [(('lizing_', 45), [(('alizing_', 32), [])]),
#          (('nizing_', 18), [])])]),
#      (('ving_', 100), [(('iving_', 26), []), (('aving_', 23), [])]),
#      (('cing_', 95), [(('ncing_', 36), []), (('acing_', 22), [])]),
#      (('wing_', 79), [(('owing_', 46), [])]),
#      (('bing_', 44), [(('bbing_', 19), [])]),
#      (('xing_', 27), []),
#      (('oing_', 24), []),
#      (('fing_', 24), []),
#      (('eing_', 23), []),
#      (('uing_', 20), [])]),
#    (('ang_', 246),
#     [(('yang_', 35), []),
#      (('iang_', 29), []),
#      (('rang_', 28), []),
#      (('hang_', 23), []),
#      (('lang_', 17), [])]),
#    (('ong_', 196),
#     [(('long_', 24), []), (('zong_', 21), []), (('rong_', 17), [])]),
#    (('ung_', 95), []),
#    (('eng_', 54), [(('heng_', 18), [])])]),
#  (('es_', 4925),
#   [(('ies_', 762),
#     [(('ries_', 228),
#       [(('aries_', 67), []),
#        (('eries_', 52), []),
#        (('ories_', 33), [(('tories_', 21), [])]),
#        (('rries_', 23), []),
#        (('tries_', 21), [])]),
#      (('ties_', 180),
#       [(('ities_', 123),
#         [(('lities_', 41), [(('alities_', 25), [])]),
#          (('rities_', 21), []),
#          (('nities_', 18), [])])]),
#      (('lies_', 62), [(('llies_', 17), [])]),
#      (('cies_', 57), [(('ncies_', 34), [(('encies_', 24), [])])]),
#      (('dies_', 34), []),
#      (('gies_', 34),
#       [(('ogies_', 22), [(('logies_', 21), [(('ologies_', 17), [])])])]),
#      (('nies_', 33), []),
#      (('fies_', 26), [(('ifies_', 23), [])]),
#      (('hies_', 21), [])]),
#    (('tes_', 608),
#     [(('ates_', 310),
#       [(('rates_', 64), []),
#        (('lates_', 45), [(('ulates_', 20), [])]),
#        (('nates_', 31), []),
#        (('mates_', 27), []),
#        (('tates_', 22), []),
#        (('iates_', 22), []),
#        (('cates_', 21), []),
#        (('gates_', 17), [])]),
#      (('ites_', 102), [(('lites_', 17), [])]),
#      (('utes_', 35), []),
#      (('ytes_', 31), [(('cytes_', 17), [(('ocytes_', 17), [])])]),
#      (('ntes_', 28), []),
#      (('ttes_', 26), [(('ettes_', 23), [])]),
#      (('otes_', 24), []),
#      (('etes_', 20), [])]),
#    (('les_', 541),
#     [(('bles_', 74), [(('ables_', 34), [])]),
#      (('ales_', 60), []),
#      (('lles_', 51), [(('elles_', 23), [])]),
#      (('cles_', 48), [(('icles_', 17), [])]),
#      (('iles_', 45), []),
#      (('oles_', 39), []),
#      (('tles_', 31), []),
#      (('ples_', 29), []),
#      (('ules_', 28), []),
#      (('gles_', 27), []),
#      (('kles_', 21), []),
#      (('yles_', 19), []),
#      (('dles_', 19), []),
#      (('eles_', 17), [])]),
#    (('ses_', 392),
#     [(('sses_', 111),
#       [(('esses_', 63), [(('resses_', 26), [])]), (('asses_', 28), [])]),
#      (('uses_', 74), [(('ouses_', 33), [(('houses_', 28), [])])]),
#      (('ases_', 55), []),
#      (('ises_', 55), []),
#      (('oses_', 30), []),
#      (('rses_', 23), [])]),
#    (('nes_', 392),
#     [(('ines_', 151), [(('lines_', 42), [])]),
#      (('ones_', 80), [(('tones_', 33), [(('stones_', 24), [])])]),
#      (('anes_', 39), []),
#      (('enes_', 32), []),
#      (('nnes_', 24), [])]),
#    (('res_', 355),
#     [(('ures_', 94),
#       [(('tures_', 59), [(('ctures_', 18), [])]), (('sures_', 17), [])]),
#      (('ores_', 61), []),
#      (('ares_', 54), []),
#      (('ires_', 54), []),
#      (('eres_', 25), []),
#      (('tres_', 19), [])]),
#    (('ces_', 250),
#     [(('nces_', 118), [(('ances_', 61), []), (('ences_', 47), [])]),
#      (('ices_', 53), []),
#      (('aces_', 35), [])]),
#    (('des_', 248),
#     [(('ides_', 90), [(('rides_', 17), [])]),
#      (('ades_', 52), []),
#      (('odes_', 33), []),
#      (('udes_', 27), []),
#      (('edes_', 18), [])]),
#    (('ves_', 213),
#     [(('ives_', 87), [(('tives_', 47), [(('atives_', 23), [])])]),
#      (('aves_', 39), []),
#      (('lves_', 27), []),
#      (('eves_', 21), []),
#      (('oves_', 19), [])]),
#    (('ges_', 193),
#     [(('ages_', 94), [(('tages_', 19), []), (('rages_', 18), [])]),
#      (('nges_', 26), []),
#      (('dges_', 24), []),
#      (('rges_', 22), [])]),
#    (('hes_', 191),
#     [(('ches_', 112),
#       [(('tches_', 30), []), (('aches_', 22), []), (('nches_', 22), [])]),
#      (('shes_', 55), [(('ishes_', 28), [])]),
#      (('thes_', 19), [])]),
#    (('mes_', 136),
#     [(('ames_', 29), []), (('omes_', 28), []), (('imes_', 26), [])]),
#    (('kes_', 102), [(('akes_', 38), []), (('okes_', 21), [])]),
#    (('ees_', 97), [(('tees_', 19), [])]),
#    (('ues_', 90), [(('ques_', 32), []), (('gues_', 28), [])]),
#    (('pes_', 84), [(('opes_', 27), []), (('apes_', 18), [])]),
#    (('zes_', 73), [(('izes_', 51), [(('lizes_', 17), [])])]),
#    (('oes_', 51), []),
#    (('xes_', 42), []),
#    (('bes_', 39), []),
#    (('yes_', 21), []),
#    (('wes_', 20), [])]),
#  (('er_', 4427),
#   [(('ter_', 751),
#     [(('ster_', 252),
#       [(('aster_', 66), [(('master_', 33), [])]),
#        (('ester_', 56), [(('hester_', 17), [])]),
#        (('ister_', 43), []),
#        (('uster_', 20), [])]),
#      (('ater_', 89), [(('water_', 43), []), (('eater_', 21), [])]),
#      (('tter_', 82),
#       [(('itter_', 21), []), (('etter_', 18), []), (('atter_', 18), [])]),
#      (('eter_', 64), [(('meter_', 35), [(('ometer_', 22), [])])]),
#      (('nter_', 60), [(('enter_', 17), []), (('inter_', 17), [])]),
#      (('iter_', 36), []),
#      (('rter_', 32), []),
#      (('hter_', 30), [(('ghter_', 22), [])]),
#      (('lter_', 27), []),
#      (('uter_', 17), [])]),
#    (('der_', 390),
#     [(('nder_', 153),
#       [(('ander_', 59), [(('lander_', 20), [])]),
#        (('ender_', 35), []),
#        (('inder_', 32), []),
#        (('under_', 20), [])]),
#      (('lder_', 61), [(('older_', 29), [(('holder_', 21), [])])]),
#      (('ader_', 42), []),
#      (('ider_', 28), []),
#      (('dder_', 25), []),
#      (('rder_', 25), []),
#      (('eder_', 17), [])]),
#    (('ler_', 376),
#     [(('ller_', 95), [(('eller_', 31), []), (('iller_', 27), [])]),
#      (('sler_', 34), []),
#      (('dler_', 30), []),
#      (('tler_', 30), []),
#      (('gler_', 23), []),
#      (('iler_', 22), []),
#      (('aler_', 17), [])]),
#    (('ner_', 352),
#     [(('iner_', 59), []),
#      (('nner_', 49), []),
#      (('oner_', 39), []),
#      (('rner_', 29), []),
#      (('tner_', 25), []),
#      (('ener_', 22), []),
#      (('hner_', 21), []),
#      (('sner_', 20), [])]),
#    (('ier_', 295),
#     [(('nier_', 41), []),
#      (('lier_', 37), []),
#      (('rier_', 36), []),
#      (('tier_', 32), []),
#      (('sier_', 20), []),
#      (('fier_', 17), [])]),
#    (('ger_', 292),
#     [(('nger_', 122),
#       [(('inger_', 67), [(('linger_', 17), [])]), (('anger_', 29), [])]),
#      (('rger_', 37), [(('erger_', 21), [(('berger_', 17), [])])]),
#      (('gger_', 34), []),
#      (('ager_', 29), []),
#      (('iger_', 22), [])]),
#    (('her_', 287),
#     [(('cher_', 104), [(('tcher_', 22), []), (('acher_', 18), [])]),
#      (('ther_', 84), [(('ather_', 26), [])]),
#      (('sher_', 42), []),
#      (('pher_', 32),
#       [(('apher_', 24), [(('rapher_', 24), [(('grapher_', 24), [])])])])]),
#    (('ker_', 275),
#     [(('cker_', 80),
#       [(('icker_', 22), []), (('acker_', 18), []), (('ecker_', 17), [])]),
#      (('aker_', 66), [(('maker_', 30), [])]),
#      (('nker_', 25), []),
#      (('oker_', 20), []),
#      (('rker_', 19), [])]),
#    (('mer_', 207),
#     [(('mmer_', 45), []),
#      (('imer_', 30), []),
#      (('omer_', 24), []),
#      (('amer_', 24), []),
#      (('lmer_', 23), []),
#      (('rmer_', 19), [])]),
#    (('per_', 192),
#     [(('pper_', 61), [(('ipper_', 19), [])]),
#      (('eper_', 30), [(('eeper_', 24), [(('keeper_', 17), [])])]),
#      (('mper_', 22), []),
#      (('oper_', 22), [])]),
#    (('ver_', 180),
#     [(('over_', 60), []),
#      (('ever_', 32), []),
#      (('iver_', 30), []),
#      (('aver_', 26), [])]),
#    (('ser_', 128), [(('sser_', 31), []), (('iser_', 30), [])]),
#    (('ber_', 125), [(('mber_', 39), [])]),
#    (('zer_', 85), [(('izer_', 24), []), (('tzer_', 19), [])]),
#    (('rer_', 82), [(('erer_', 24), [])]),
#    (('yer_', 81), [(('ayer_', 29), []), (('eyer_', 19), [])]),
#    (('fer_', 79), [(('ffer_', 33), [])]),
#    (('wer_', 69), [(('ower_', 51), [])]),
#    (('eer_', 63), []),
#    (('cer_', 49), [(('ncer_', 19), [])]),
#    (('uer_', 40), [(('auer_', 21), [])])]),
#  (('on_', 4168),
#   [(('ion_', 1773),
#     [(('tion_', 1451),
#       [(('ation_', 1098),
#         [(('zation_', 165), [(('ization_', 165), [])]),
#          (('cation_', 137), [(('ication_', 105), []), (('ocation_', 18), [])]),
#          (('ration_', 135),
#           [(('eration_', 43), []),
#            (('oration_', 19), []),
#            (('tration_', 18), [])]),
#          (('tation_', 130),
#           [(('itation_', 38), []),
#            (('ntation_', 31), []),
#            (('station_', 17), [])]),
#          (('lation_', 117), [(('ulation_', 51), [])]),
#          (('nation_', 90), [(('ination_', 52), [])]),
#          (('sation_', 87), [(('isation_', 77), [])]),
#          (('iation_', 51), []),
#          (('mation_', 39), []),
#          (('gation_', 32), []),
#          (('dation_', 26), []),
#          (('vation_', 26), []),
#          (('uation_', 24), [])]),
#        (('ction_', 142),
#         [(('ection_', 53), []),
#          (('action_', 28), []),
#          (('uction_', 24), []),
#          (('iction_', 20), [])]),
#        (('ition_', 73), [(('sition_', 24), [(('osition_', 20), [])])]),
#        (('ption_', 46), []),
#        (('ution_', 36), [])]),
#      (('sion_', 169),
#       [(('ssion_', 55), [(('ession_', 32), []), (('ission_', 17), [])]),
#        (('ision_', 29), [(('vision_', 19), [])]),
#        (('usion_', 27), []),
#        (('nsion_', 19), [(('ension_', 17), [])]),
#        (('rsion_', 17), [])]),
#      (('lion_', 39), [(('llion_', 21), [])]),
#      (('rion_', 26), []),
#      (('gion_', 17), []),
#      (('nion_', 17), [])]),
#    (('ton_', 839),
#     [(('gton_', 137),
#       [(('ngton_', 134),
#         [(('ington_', 132),
#           [(('rington_', 25), []),
#            (('lington_', 21), []),
#            (('dington_', 19), [])])])]),
#      (('ston_', 135),
#       [(('eston_', 25), []), (('iston_', 24), []), (('lston_', 18), [])]),
#      (('rton_', 96), [(('erton_', 56), [])]),
#      (('nton_', 82),
#       [(('anton_', 20), []), (('inton_', 19), []), (('enton_', 18), [])]),
#      (('lton_', 62), []),
#      (('eton_', 58), [(('leton_', 34), [])]),
#      (('pton_', 44), [(('mpton_', 30), [(('ampton_', 18), [])])]),
#      (('tton_', 43), []),
#      (('hton_', 30), [(('ghton_', 25), [])]),
#      (('aton_', 25), []),
#      (('yton_', 23), []),
#      (('xton_', 22), [])]),
#    (('son_', 510),
#     [(('nson_', 74), [(('inson_', 29), [])]),
#      (('sson_', 71), []),
#      (('rson_', 69), [(('erson_', 55), [])]),
#      (('ison_', 57), []),
#      (('lson_', 45), [(('elson_', 20), [])]),
#      (('tson_', 25), []),
#      (('eson_', 21), []),
#      (('ason_', 21), []),
#      (('dson_', 19), [])]),
#    (('ron_', 164),
#     [(('tron_', 32), []), (('eron_', 26), []), (('aron_', 18), [])]),
#    (('don_', 147), [(('ndon_', 36), []), (('rdon_', 17), [])]),
#    (('lon_', 100), [(('llon_', 29), [])]),
#    (('oon_', 75), []),
#    (('mon_', 73), []),
#    (('eon_', 73), []),
#    (('non_', 68), [(('nnon_', 20), [])]),
#    (('hon_', 54), []),
#    (('gon_', 47), [(('agon_', 18), [])]),
#    (('con_', 43), []),
#    (('yon_', 31), []),
#    (('bon_', 29), []),
#    (('zon_', 20), []),
#    (('pon_', 18), []),
#    (('xon_', 18), []),
#    (('kon_', 17), [])]),
#  (('_co', 3272),
#   [(('_con', 1042),
#     [(('_cons', 227),
#       [(('_const', 74),
#         [(('_constr', 30), [(('_constru', 18), [])]),
#          (('_consta', 21), [(('_constan', 18), [])]),
#          (('_consti', 20), [(('_constit', 19), [])])]),
#        (('_conse', 45), [(('_conser', 20), [(('_conserv', 20), [])])]),
#        (('_consu', 34), [(('_consul', 18), [])]),
#        (('_consi', 25), []),
#        (('_conso', 20), [])]),
#      (('_cont', 194),
#       [(('_contr', 81), [(('_contra', 52), [])]),
#        (('_conte', 48), [(('_contem', 19), [(('_contemp', 19), [])])]),
#        (('_conti', 30), [(('_contin', 26), [])]),
#        (('_conta', 25), [])]),
#      (('_conc', 136),
#       [(('_conce', 65), []), (('_conco', 17), []), (('_concu', 17), [])]),
#      (('_conf', 124),
#       [(('_confi', 37), []), (('_confe', 33), []), (('_confo', 17), [])]),
#      (('_conv', 88),
#       [(('_conve', 59), [(('_conver', 27), []), (('_conven', 19), [])])]),
#      (('_cond', 70), [(('_conde', 22), []), (('_condo', 17), [])]),
#      (('_cong', 49), [(('_congr', 27), [(('_congre', 18), [])])]),
#      (('_conn', 48), [(('_conne', 26), [])]),
#      (('_conj', 27), [(('_conju', 21), [])])]),
#    (('_com', 527),
#     [(('_comp', 223),
#       [(('_compl', 53), [(('_comple', 22), []), (('_compli', 18), [])]),
#        (('_compa', 47), []),
#        (('_compe', 32), [(('_compet', 17), [])]),
#        (('_compr', 28), [(('_compre', 20), [])]),
#        (('_compo', 26), [(('_compos', 19), [])]),
#        (('_compu', 24), [])]),
#      (('_comm', 162),
#       [(('_comme', 54), [(('_commen', 31), [])]),
#        (('_commu', 40), [(('_commun', 31), [(('_communi', 24), [])])]),
#        (('_commi', 26), []),
#        (('_comma', 21), [(('_comman', 18), [(('_command', 18), [])])]),
#        (('_commo', 20), [])]),
#      (('_comb', 35), []),
#      (('_come', 29), []),
#      (('_comi', 21), [])]),
#    (('_cor', 371),
#     [(('_corr', 72), [(('_corre', 35), [])]),
#      (('_corn', 55), [(('_corne', 30), [])]),
#      (('_cord', 34), []),
#      (('_cort', 28), []),
#      (('_coro', 26), [(('_coron', 18), [])]),
#      (('_corp', 23), []),
#      (('_cori', 21), []),
#      (('_corb', 17), []),
#      (('_cors', 17), [])]),
#    (('_col', 343),
#     [(('_coll', 129),
#       [(('_colle', 43), [(('_collec', 20), [(('_collect', 20), [])])]),
#        (('_colla', 34), []),
#        (('_colli', 32), [])]),
#      (('_colo', 85),
#       [(('_colon', 37), [(('_coloni', 24), [])]), (('_color', 17), [])]),
#      (('_colu', 26), [(('_colum', 22), [])]),
#      (('_cole', 25), [])]),
#    (('_cou', 209),
#     [(('_coun', 92),
#       [(('_count', 70), [(('_counte', 51), [(('_counter', 48), [])])])]),
#      (('_cour', 51), [(('_court', 28), [])]),
#      (('_coup', 23), [])]),
#    (('_coo', 96), [(('_cook', 22), []), (('_cool', 20), [])]),
#    (('_cop', 85), [(('_copp', 25), [])]),
#    (('_cos', 84), [(('_cost', 30), []), (('_cosm', 21), [])]),
#    (('_coa', 70), []),
#    (('_coc', 60), [(('_cock', 29), [])]),
#    (('_cow', 51), []),
#    (('_cot', 50), [(('_cott', 24), [])]),
#    (('_cod', 44), [(('_code', 20), [])]),
#    (('_cov', 41), [(('_cove', 29), [])]),
#    (('_cob', 38), []),
#    (('_coe', 34), []),
#    (('_coi', 28), []),
#    (('_coh', 24), []),
#    (('_cog', 24), []),
#    (('_cof', 20), [])]),
#  (('an_', 3186),
#   [(('man_', 771),
#     [(('rman_', 117), [(('erman_', 65), []), (('arman_', 17), [])]),
#      (('eman_', 71), []),
#      (('lman_', 67), [(('llman_', 22), []), (('elman_', 18), [])]),
#      (('sman_', 63), []),
#      (('hman_', 51), [(('chman_', 18), [])]),
#      (('tman_', 50), []),
#      (('oman_', 47), [(('woman_', 22), [])]),
#      (('dman_', 43), []),
#      (('kman_', 39), [(('ckman_', 20), [])]),
#      (('yman_', 39), []),
#      (('aman_', 34), []),
#      (('iman_', 28), []),
#      (('uman_', 25), []),
#      (('gman_', 23), [])]),
#    (('ian_', 689),
#     [(('rian_', 145),
#       [(('arian_', 55), [(('tarian_', 20), [])]),
#        (('erian_', 26), []),
#        (('orian_', 17), [])]),
#      (('nian_', 111),
#       [(('onian_', 38), []), (('anian_', 27), []), (('inian_', 25), [])]),
#      (('lian_', 63), []),
#      (('sian_', 59), [(('esian_', 17), [])]),
#      (('dian_', 55), []),
#      (('tian_', 50), []),
#      (('cian_', 44), [(('ician_', 27), [])]),
#      (('vian_', 26), []),
#      (('hian_', 26), []),
#      (('bian_', 26), []),
#      (('gian_', 18), []),
#      (('mian_', 17), [])]),
#    (('han_', 198),
#     [(('shan_', 44), []), (('ahan_', 30), []), (('than_', 23), [])]),
#    (('ran_', 152),
#     [(('aran_', 37), []), (('oran_', 20), []), (('eran_', 18), [])]),
#    (('gan_', 150),
#     [(('igan_', 39), []),
#      (('agan_', 28), []),
#      (('egan_', 21), []),
#      (('rgan_', 18), [])]),
#    (('tan_', 140),
#     [(('stan_', 45), [(('istan_', 22), [])]), (('atan_', 23), [])]),
#    (('lan_', 128), [(('llan_', 22), [])]),
#    (('ean_', 104), [(('lean_', 18), [])]),
#    (('nan_', 101), [(('nnan_', 20), [])]),
#    (('yan_', 90), [(('ayan_', 25), [])]),
#    (('van_', 74), [(('avan_', 21), [])]),
#    (('dan_', 73), []),
#    (('can_', 66), [(('ican_', 24), [])]),
#    (('san_', 65), []),
#    (('uan_', 61), []),
#    (('wan_', 56), []),
#    (('ban_', 48), []),
#    (('kan_', 45), []),
#    (('jan_', 40), []),
#    (('pan_', 39), []),
#    (('aan_', 30), []),
#    (('fan_', 23), []),
#    (('oan_', 20), []),
#    (('zan_', 20), [])]),
#  (('_ma', 2971),
#   [(('_mar', 623),
#     [(('_mari', 105), [(('_marin', 24), [])]),
#      (('_mart', 67), [(('_marti', 32), [(('_martin', 19), [])])]),
#      (('_marc', 61), [(('_march', 22), [])]),
#      (('_marg', 53), [(('_marga', 19), [])]),
#      (('_mars', 47), [(('_marsh', 24), [])]),
#      (('_mark', 46), [(('_marke', 18), [])]),
#      (('_mara', 40), []),
#      (('_marq', 22), [(('_marqu', 22), [])]),
#      (('_marl', 22), []),
#      (('_marr', 22), []),
#      (('_mary', 20), []),
#      (('_maro', 18), [])]),
#    (('_man', 445),
#     [(('_mand', 68), [(('_manda', 28), [])]),
#      (('_mani', 63), []),
#      (('_mana', 44), []),
#      (('_mang', 34), []),
#      (('_mant', 33), []),
#      (('_mann', 32), []),
#      (('_manu', 28), []),
#      (('_mans', 28), []),
#      (('_mano', 24), [])]),
#    (('_mat', 238),
#     [(('_matt', 47), []),
#      (('_math', 34), []),
#      (('_mate', 31), [(('_mater', 20), [])]),
#      (('_mata', 27), []),
#      (('_mats', 22), [(('_matsu', 19), [])]),
#      (('_matr', 21), []),
#      (('_mati', 18), []),
#      (('_matc', 18), [(('_match', 18), [])])]),
#    (('_mal', 234),
#     [(('_mala', 58), []),
#      (('_mall', 34), []),
#      (('_mali', 28), []),
#      (('_male', 19), []),
#      (('_malt', 19), [])]),
#    (('_mac', 222),
#     [(('_mach', 35), [(('_machi', 20), [])]),
#      (('_maca', 26), []),
#      (('_mack', 25), []),
#      (('_macr', 22), [(('_macro', 18), [])])]),
#    (('_mas', 214),
#     [(('_mass', 47), [(('_massa', 17), [])]),
#      (('_mast', 46), [(('_maste', 28), [(('_master', 25), [])])]),
#      (('_masa', 30), [])]),
#    (('_mag', 163),
#     [(('_magn', 56), [(('_magne', 20), []), (('_magni', 18), [])]),
#      (('_magi', 24), [])]),
#    (('_mad', 121), [(('_madh', 24), [])]),
#    (('_mah', 109), [(('_maha', 58), [])]),
#    (('_mai', 105), [(('_main', 39), [])]),
#    (('_mau', 71), [(('_maur', 26), [])]),
#    (('_may', 70), []),
#    (('_mak', 61), []),
#    (('_maj', 46), [(('_majo', 17), [])]),
#    (('_max', 44), [(('_maxi', 36), [(('_maxim', 28), [])])]),
#    (('_mam', 40), []),
#    (('_maz', 38), []),
#    (('_map', 25), []),
#    (('_maa', 23), []),
#    (('_mae', 21), [])]),
#  (('_re', 2583),
#   [(('_rec', 311),
#     [(('_reco', 116),
#       [(('_recon', 49), [(('_recons', 18), [])]), (('_recom', 17), [])]),
#      (('_rece', 38), []),
#      (('_reci', 28), []),
#      (('_recu', 25), []),
#      (('_rect', 23), []),
#      (('_reca', 22), []),
#      (('_recr', 18), [])]),
#    (('_res', 286),
#     [(('_rest', 59), [(('_restr', 20), [])]),
#      (('_rese', 47), []),
#      (('_resi', 46), [(('_resid', 20), [])]),
#      (('_resp', 37), [(('_respo', 17), [(('_respon', 17), [])])]),
#      (('_resu', 31), []),
#      (('_reso', 31), [])]),
#    (('_rep', 224),
#     [(('_repr', 52),
#       [(('_repre', 19), [(('_repres', 18), [])]), (('_repro', 18), [])]),
#      (('_repe', 39), []),
#      (('_repl', 36), []),
#      (('_repu', 36), []),
#      (('_repa', 28), []),
#      (('_repo', 24), [])]),
#    (('_rea', 192),
#     [(('_real', 44), [(('_reali', 25), [])]),
#      (('_reas', 30), [(('_reass', 22), [])]),
#      (('_reac', 28), [(('_react', 19), [])]),
#      (('_read', 22), []),
#      (('_rear', 22), [])]),
#    (('_red', 171),
#     [(('_rede', 39), []), (('_redi', 21), []), (('_redu', 19), [])]),
#    (('_ref', 150),
#     [(('_refu', 32), []),
#      (('_refr', 26), []),
#      (('_refe', 23), [(('_refer', 22), [])]),
#      (('_refo', 22), [(('_refor', 17), [])]),
#      (('_refl', 21), [(('_refle', 17), [])]),
#      (('_refi', 21), [])]),
#    (('_ret', 149),
#     [(('_retr', 47), []), (('_reta', 30), []), (('_reti', 29), [])]),
#    (('_reg', 145),
#     [(('_regi', 47), []),
#      (('_regu', 22), [(('_regul', 18), [(('_regula', 17), [])])]),
#      (('_rega', 21), []),
#      (('_regr', 19), [])]),
#    (('_rev', 142),
#     [(('_reve', 53), [(('_rever', 28), [])]),
#      (('_revi', 42), []),
#      (('_revo', 28), [(('_revol', 24), [])])]),
#    (('_rei', 142),
#     [(('_rein', 64), []), (('_reic', 20), [(('_reich', 20), [])])]),
#    (('_ren', 125),
#     [(('_rend', 21), []),
#      (('_rene', 18), []),
#      (('_rena', 17), []),
#      (('_reno', 17), [])]),
#    (('_rem', 125),
#     [(('_remi', 32), []),
#      (('_rema', 31), []),
#      (('_remo', 27), []),
#      (('_reme', 19), [])]),
#    (('_rel', 112),
#     [(('_reli', 42), []),
#      (('_rela', 35), [(('_relat', 17), [])]),
#      (('_rele', 17), [])]),
#    (('_reb', 66), [(('_rebu', 19), [])]),
#    (('_ree', 56), []),
#    (('_reh', 28), []),
#    (('_reu', 26), []),
#    (('_reo', 24), []),
#    (('_rew', 20), []),
#    (('_req', 20), [(('_requ', 20), [])]),
#    (('_rej', 19), []),
#    (('_rey', 17), [])]),
#  (('rs_', 2279),
#   [(('ers_', 1649),
#     [(('ters_', 307),
#       [(('sters_', 83), [(('asters_', 23), [])]),
#        (('tters_', 45), []),
#        (('eters_', 30), [(('meters_', 17), [])]),
#        (('nters_', 28), []),
#        (('aters_', 28), []),
#        (('iters_', 20), [])]),
#      (('ders_', 177),
#       [(('nders_', 74), [(('anders_', 24), []), (('enders_', 22), [])]),
#        (('lders_', 37), [(('olders_', 18), [])]),
#        (('aders_', 18), [])]),
#      (('kers_', 138),
#       [(('akers_', 40), [(('makers_', 20), [])]), (('ckers_', 36), [])]),
#      (('lers_', 125), [(('llers_', 40), [])]),
#      (('hers_', 103),
#       [(('thers_', 32), []),
#        (('chers_', 27), []),
#        (('shers_', 22), []),
#        (('phers_', 19), [])]),
#      (('ners_', 99),
#       [(('iners_', 26), []), (('oners_', 19), []), (('nners_', 19), [])]),
#      (('pers_', 93), [(('ppers_', 32), [])]),
#      (('vers_', 86), [(('overs_', 23), []), (('ivers_', 19), [])]),
#      (('gers_', 77), [(('ngers_', 29), []), (('ggers_', 17), [])]),
#      (('iers_', 72), []),
#      (('mers_', 66), []),
#      (('sers_', 46), [(('isers_', 17), [])]),
#      (('rers_', 36), []),
#      (('wers_', 36), [(('owers_', 27), [])]),
#      (('yers_', 34), [(('ayers_', 18), [])]),
#      (('bers_', 33), []),
#      (('cers_', 29), []),
#      (('eers_', 28), []),
#      (('fers_', 21), []),
#      (('zers_', 20), [])]),
#    (('ors_', 328),
#     [(('tors_', 207),
#       [(('ators_', 97), [(('rators_', 28), [])]),
#        (('ctors_', 46), [(('ectors_', 20), [])]),
#        (('itors_', 18), [])]),
#      (('sors_', 26), [])]),
#    (('ars_', 163), [(('lars_', 28), []), (('ears_', 25), [])]),
#    (('urs_', 83), [(('ours_', 40), [])]),
#    (('irs_', 43), [(('airs_', 19), [])])]),
#  (('_ca', 2181),
#   [(('_car', 540),
#     [(('_carr', 60), [(('_carri', 18), [])]),
#      (('_card', 52), [(('_cardi', 24), [])]),
#      (('_cart', 52), []),
#      (('_carb', 47), [(('_carbo', 27), [(('_carbon', 17), [])])]),
#      (('_cara', 40), []),
#      (('_carl', 39), []),
#      (('_carn', 37), []),
#      (('_cari', 37), []),
#      (('_caro', 35), [(('_carol', 22), [])]),
#      (('_carp', 34), []),
#      (('_care', 29), []),
#      (('_carm', 22), [])]),
#    (('_can', 265),
#     [(('_cant', 54), []),
#      (('_cand', 38), [(('_candi', 18), [])]),
#      (('_cana', 37), []),
#      (('_cann', 34), []),
#      (('_cano', 30), []),
#      (('_canc', 18), [])]),
#    (('_cal', 241),
#     [(('_call', 56), [(('_calli', 18), [])]),
#      (('_cali', 40), []),
#      (('_cala', 26), []),
#      (('_calc', 20), []),
#      (('_calv', 17), [])]),
#    (('_cas', 226),
#     [(('_cast', 86),
#       [(('_caste', 30), [(('_castel', 24), [(('_castell', 20), [])])])]),
#      (('_cass', 46), [(('_cassi', 20), [])]),
#      (('_case', 17), [])]),
#    (('_cat', 208),
#     [(('_cata', 62), [(('_catal', 31), [])]),
#      (('_cate', 43), []),
#      (('_cath', 36), []),
#      (('_catt', 19), [])]),
#    (('_cap', 172),
#     [(('_capi', 43), [(('_capit', 35), [(('_capita', 22), [])])]),
#      (('_capt', 24), []),
#      (('_cape', 20), []),
#      (('_capr', 17), [])]),
#    (('_cam', 160),
#     [(('_camp', 66), [(('_campa', 19), [])]),
#      (('_came', 28), []),
#      (('_camb', 20), [])]),
#    (('_cau', 52), []),
#    (('_cab', 52), []),
#    (('_cav', 51), [(('_cava', 21), []), (('_cave', 18), [])]),
#    (('_cad', 48), []),
#    (('_cai', 31), []),
#    (('_cae', 29), []),
#    (('_cac', 22), [])]),
#  (('le_', 2083),
#   [(('ble_', 620),
#     [(('able_', 446),
#       [(('table_', 109), [(('itable_', 24), []), (('ntable_', 17), [])]),
#        (('rable_', 63), [(('erable_', 23), [])]),
#        (('nable_', 39), []),
#        (('eable_', 35), []),
#        (('iable_', 28), []),
#        (('dable_', 25), []),
#        (('sable_', 20), []),
#        (('vable_', 20), []),
#        (('kable_', 18), [])]),
#      (('ible_', 99), [(('sible_', 37), []), (('tible_', 22), [])]),
#      (('mble_', 30), []),
#      (('bble_', 24), [])]),
#    (('lle_', 431),
#     [(('ille_', 317),
#       [(('ville_', 271),
#         [(('sville_', 80), [(('esville_', 19), [])]),
#          (('nville_', 47), [(('onville_', 20), [])]),
#          (('eville_', 38), []),
#          (('rville_', 25), [])])]),
#      (('elle_', 72), []),
#      (('alle_', 25), [])]),
#    (('ale_', 249),
#     [(('dale_', 104), [(('sdale_', 28), []), (('ndale_', 24), [])]),
#      (('nale_', 17), [])]),
#    (('ile_', 131), [(('tile_', 27), []), (('hile_', 20), [])]),
#    (('ole_', 99), [(('hole_', 23), []), (('pole_', 17), [])]),
#    (('tle_', 77), [(('ttle_', 28), []), (('stle_', 27), [])]),
#    (('gle_', 58), [(('ngle_', 31), [])]),
#    (('dle_', 57), [(('ddle_', 20), []), (('ndle_', 19), [])]),
#    (('ple_', 56), []),
#    (('cle_', 55), [(('icle_', 22), [])]),
#    (('ule_', 50), []),
#    (('ele_', 44), []),
#    (('yle_', 40), []),
#    (('kle_', 39), [(('ckle_', 20), [])]),
#    (('rle_', 19), [])]),
#  (('ns_', 2012),
#   [(('ons_', 948),
#     [(('ions_', 686),
#       [(('tions_', 551),
#         [(('ations_', 344),
#           [(('tations_', 60), []),
#            (('rations_', 52), []),
#            (('cations_', 45), []),
#            (('lations_', 36), []),
#            (('nations_', 35), []),
#            (('zations_', 22), [])]),
#          (('ctions_', 85), [(('ections_', 32), [])]),
#          (('itions_', 48), [(('sitions_', 19), [])]),
#          (('ptions_', 25), [])]),
#        (('sions_', 90), [(('ssions_', 36), [(('essions_', 22), [])])])]),
#      (('sons_', 50), []),
#      (('tons_', 31), []),
#      (('oons_', 31), []),
#      (('rons_', 27), []),
#      (('mons_', 25), [])]),
#    (('ans_', 454),
#     [(('ians_', 231),
#       [(('rians_', 46), [(('arians_', 20), [])]),
#        (('nians_', 41), []),
#        (('sians_', 27), []),
#        (('cians_', 24), [(('icians_', 18), [])]),
#        (('dians_', 19), [])]),
#      (('mans_', 29), []),
#      (('eans_', 27), []),
#      (('cans_', 26), []),
#      (('tans_', 20), []),
#      (('rans_', 17), [])]),
#    (('ins_', 254),
#     [(('ains_', 53), []),
#      (('kins_', 37), []),
#      (('lins_', 27), []),
#      (('gins_', 21), [])]),
#    (('ens_', 218), [(('tens_', 23), []), (('gens_', 21), [])]),
#    (('rns_', 54), [(('erns_', 19), [])]),
#    (('wns_', 27), [(('owns_', 21), [])]),
#    (('uns_', 22), [])]),
#  (('al_', 1915),
#   [(('cal_', 322),
#     [(('ical_', 288),
#       [(('gical_', 91), [(('ogical_', 84), [(('logical_', 83), [])])]),
#        (('tical_', 54), []),
#        (('rical_', 27), []),
#        (('nical_', 23), []),
#        (('hical_', 22), []),
#        (('mical_', 21), [])])]),
#    (('nal_', 288),
#     [(('onal_', 180),
#       [(('ional_', 147),
#         [(('tional_', 119), [(('ational_', 57), []), (('ctional_', 24), [])]),
#          (('sional_', 22), [])])]),
#      (('inal_', 48), []),
#      (('rnal_', 18), [])]),
#    (('ial_', 254),
#     [(('rial_', 72), [(('orial_', 32), [(('torial_', 23), [])])]),
#      (('cial_', 47), []),
#      (('tial_', 45), [(('ntial_', 31), [(('ential_', 28), [])])]),
#      (('nial_', 28), [])]),
#    (('ral_', 189),
#     [(('ural_', 50), [(('tural_', 27), [])]),
#      (('eral_', 37), []),
#      (('oral_', 35), []),
#      (('tral_', 20), [])]),
#    (('tal_', 163),
#     [(('ntal_', 55), [(('ental_', 43), [(('mental_', 28), [])])]),
#      (('ital_', 27), []),
#      (('stal_', 23), [])]),
#    (('dal_', 79), [(('idal_', 27), []), (('ndal_', 18), [])]),
#    (('eal_', 69), [(('real_', 18), [])]),
#    (('hal_', 67), [(('thal_', 21), []), (('chal_', 17), [])]),
#    (('ual_', 64), [(('tual_', 23), [])]),
#    (('mal_', 64), [(('rmal_', 17), [])]),
#    (('sal_', 53), []),
#    (('gal_', 51), []),
#    (('val_', 50), []),
#    (('bal_', 34), []),
#    (('pal_', 32), []),
#    (('wal_', 28), []),
#    (('aal_', 23), []),
#    (('kal_', 18), []),
#    (('yal_', 17), [])]),
#  (('_in', 1837),
#   [(('_int', 508),
#     [(('_inte', 405),
#       [(('_inter', 331),
#         [(('_interc', 45), [(('_interco', 20), [])]),
#          (('_intern', 36), [(('_interna', 22), [])]),
#          (('_interm', 29), []),
#          (('_interp', 28), []),
#          (('_interl', 26), []),
#          (('_interr', 26), []),
#          (('_inters', 22), []),
#          (('_interv', 22), []),
#          (('_interf', 21), [])]),
#        (('_inten', 26), []),
#        (('_integ', 22), [(('_integr', 19), [])]),
#        (('_intel', 18), [])]),
#      (('_intr', 63), [(('_intra', 22), []), (('_intro', 18), [])])]),
#    (('_ins', 223),
#     [(('_inst', 83),
#       [(('_insti', 33), []),
#        (('_insta', 27), []),
#        (('_instr', 20), [(('_instru', 20), [])])]),
#      (('_insu', 40), [(('_insur', 18), [])]),
#      (('_inse', 29), []),
#      (('_insi', 28), [])]),
#    (('_ind', 207),
#     [(('_indi', 80), [(('_indic', 19), [])]),
#      (('_indu', 50),
#       [(('_induc', 21), []),
#        (('_indus', 19), [(('_indust', 18), [(('_industr', 18), [])])])]),
#      (('_inde', 44), []),
#      (('_indo', 21), [])]),
#    (('_inf', 186),
#     [(('_infl', 40), []),
#      (('_infi', 38), []),
#      (('_infe', 30), []),
#      (('_info', 29), [(('_infor', 18), [(('_inform', 18), [])])]),
#      (('_infa', 22), [])]),
#    (('_inc', 179),
#     [(('_inco', 50), [(('_incon', 19), [])]),
#      (('_inci', 25), []),
#      (('_incu', 23), []),
#      (('_inca', 21), []),
#      (('_incr', 19), []),
#      (('_incl', 18), [])]),
#    (('_inv', 133),
#     [(('_inve', 62),
#       [(('_inves', 24), [(('_invest', 23), [])]), (('_inver', 23), [])]),
#      (('_inva', 25), []),
#      (('_invi', 23), []),
#      (('_invo', 21), [])]),
#    (('_ing', 63), [(('_inge', 18), [])]),
#    (('_ina', 53), []),
#    (('_ine', 49), []),
#    (('_inn', 42), []),
#    (('_inh', 42), []),
#    (('_ini', 28),
#     [(('_init', 20), [(('_initi', 19), [(('_initia', 18), [])])])]),
#    (('_inj', 22), [])]),
#  (('ts_', 1835),
#   [(('nts_', 456),
#     [(('ents_', 271),
#       [(('ments_', 164), [(('ements_', 56), []), (('tments_', 20), [])]),
#        (('dents_', 18), [])]),
#      (('ants_', 120), [(('rants_', 20), []), (('tants_', 19), [])]),
#      (('ints_', 36), []),
#      (('unts_', 18), [])]),
#    (('sts_', 382),
#     [(('ists_', 273),
#       [(('lists_', 59), [(('alists_', 40), [])]),
#        (('nists_', 43), [(('onists_', 25), [(('ionists_', 17), [])])]),
#        (('gists_', 43), [(('ogists_', 39), [(('logists_', 39), [])])]),
#        (('rists_', 24), []),
#        (('tists_', 21), [])]),
#      (('asts_', 37), []),
#      (('ests_', 34), [])]),
#    (('ets_', 210),
#     [(('lets_', 49), []),
#      (('kets_', 27), [(('ckets_', 18), [])]),
#      (('nets_', 23), []),
#      (('sets_', 19), []),
#      (('rets_', 17), [])]),
#    (('ats_', 119), [(('oats_', 30), []), (('eats_', 25), [])]),
#    (('its_', 116), []),
#    (('rts_', 112),
#     [(('orts_', 36), [(('ports_', 18), [])]),
#      (('arts_', 36), []),
#      (('erts_', 27), [])]),
#    (('cts_', 100), [(('ects_', 45), []), (('acts_', 23), [])]),
#    (('uts_', 77), [(('outs_', 39), [])]),
#    (('ots_', 75), []),
#    (('hts_', 50),
#     [(('ghts_', 47), [(('ights_', 43), [(('lights_', 18), [])])])]),
#    (('lts_', 39), []),
#    (('tts_', 32), []),
#    (('pts_', 30), []),
#    (('fts_', 26), [])]),
#  (('_ba', 1828),
#   [(('_bar', 417),
#     [(('_barr', 71),
#       [(('_barri', 20), []), (('_barra', 20), []), (('_barre', 17), [])]),
#      (('_barb', 66), [(('_barbe', 25), []), (('_barba', 19), [])]),
#      (('_bart', 49), []),
#      (('_barn', 36), []),
#      (('_bara', 33), []),
#      (('_baro', 24), []),
#      (('_bard', 20), []),
#      (('_bari', 18), []),
#      (('_bare', 17), [])]),
#    (('_bal', 240),
#     [(('_ball', 78), [(('_balla', 17), [])]),
#      (('_bala', 38), []),
#      (('_bald', 21), [])]),
#    (('_ban', 213),
#     [(('_band', 57), []), (('_bang', 26), []), (('_bank', 26), [])]),
#    (('_bas', 166),
#     [(('_basi', 32), []),
#      (('_bass', 29), []),
#      (('_bast', 21), []),
#      (('_base', 19), [])]),
#    (('_bat', 143),
#     [(('_batt', 54), [(('_battl', 26), [(('_battle', 25), [])])]),
#      (('_bath', 22), []),
#      (('_bata', 19), [])]),
#    (('_bac', 125), [(('_back', 78), [])]),
#    (('_bay', 67), []),
#    (('_bag', 60), []),
#    (('_bai', 56), [(('_bail', 23), [])]),
#    (('_bab', 51), []),
#    (('_bad', 48), []),
#    (('_bak', 38), []),
#    (('_bah', 36), []),
#    (('_bau', 33), []),
#    (('_bam', 28), []),
#    (('_bap', 19), [])]),
#  (('_de', 1807),
#   [(('_dec', 204),
#     [(('_deco', 45), []),
#      (('_dece', 34), []),
#      (('_deca', 31), []),
#      (('_deci', 30), []),
#      (('_decr', 26), []),
#      (('_decl', 21), [])]),
#    (('_des', 193),
#     [(('_dest', 35), [(('_destr', 17), [])]),
#      (('_desi', 34), []),
#      (('_desp', 30), []),
#      (('_desc', 27), []),
#      (('_dese', 23), [])]),
#    (('_del', 175),
#     [(('_deli', 57), []), (('_dela', 24), []), (('_dele', 19), [])]),
#    (('_dem', 147),
#     [(('_demo', 70), [(('_demon', 20), [])]),
#      (('_deme', 25), []),
#      (('_demi', 17), [])]),
#    (('_def', 140),
#     [(('_defe', 51), [(('_defen', 25), [])]), (('_defi', 29), [])]),
#    (('_den', 136),
#     [(('_deni', 25), []), (('_dent', 22), []), (('_deno', 19), [])]),
#    (('_dep', 132),
#     [(('_depo', 32), []),
#      (('_depr', 26), []),
#      (('_depl', 17), []),
#      (('_depa', 17), []),
#      (('_depe', 17), [])]),
#    (('_dev', 122),
#     [(('_devo', 36), []),
#      (('_devi', 28), []),
#      (('_deva', 26), []),
#      (('_deve', 23), [])]),
#    (('_det', 99),
#     [(('_dete', 46), [(('_deter', 29), [])]), (('_deta', 17), [])]),
#    (('_der', 85), [(('_deri', 18), [])]),
#    (('_dea', 83), [(('_dead', 17), [])]),
#    (('_deb', 67), [(('_deba', 18), [])]),
#    (('_dee', 45), [(('_deep', 17), [])]),
#    (('_deg', 28), []),
#    (('_ded', 24), []),
#    (('_dei', 23), []),
#    (('_deu', 22), []),
#    (('_deo', 17), [])]),
#  (('_pa', 1726),
#   [(('_par', 476),
#     [(('_para', 152),
#       [(('_param', 26), []),
#        (('_paras', 20), []),
#        (('_paral', 20), []),
#        (('_parad', 17), [])]),
#      (('_part', 86), [(('_parti', 46), [(('_partic', 23), [])])]),
#      (('_park', 35), []),
#      (('_pari', 33), []),
#      (('_pare', 26), []),
#      (('_pars', 25), []),
#      (('_paro', 18), []),
#      (('_parl', 18), [])]),
#    (('_pan', 218),
#     [(('_pant', 38), []),
#      (('_pand', 32), []),
#      (('_pana', 24), []),
#      (('_panc', 22), []),
#      (('_pane', 19), []),
#      (('_pani', 18), [])]),
#    (('_pal', 198),
#     [(('_pala', 63), []),
#      (('_pall', 34), []),
#      (('_pale', 34), []),
#      (('_palm', 25), [])]),
#    (('_pat', 191),
#     [(('_patr', 63), [(('_patri', 36), []), (('_patro', 22), [])]),
#      (('_path', 35), []),
#      (('_pate', 27), []),
#      (('_patt', 21), [])]),
#    (('_pas', 131), [(('_pass', 48), []), (('_past', 40), [])]),
#    (('_pap', 71), [(('_papi', 17), []), (('_papa', 17), [])]),
#    (('_pac', 61), [(('_paci', 17), [])]),
#    (('_pad', 49), []),
#    (('_pai', 47), [(('_pain', 24), [])]),
#    (('_pau', 45), [(('_paul', 28), [])]),
#    (('_pay', 39), []),
#    (('_pav', 38), []),
#    (('_pag', 31), []),
#    (('_pam', 24), []),
#    (('_pak', 21), []),
#    (('_paw', 18), [])]),
#  (('_st', 1713),
#   [(('_sta', 486),
#     [(('_star', 98), []),
#      (('_stan', 76), [(('_stand', 28), [])]),
#      (('_stat', 73), [(('_stati', 27), []), (('_state', 25), [])]),
#      (('_stal', 37), []),
#      (('_stab', 33), []),
#      (('_stag', 22), []),
#      (('_stam', 21), []),
#      (('_stai', 20), [])]),
#    (('_str', 401),
#     [(('_stra', 156),
#       [(('_strat', 47), []),
#        (('_stran', 29), [(('_strang', 19), [])]),
#        (('_strai', 19), [])]),
#      (('_stre', 77), [(('_strea', 22), [])]),
#      (('_stri', 71), []),
#      (('_stro', 54), []),
#      (('_stru', 33), [])]),
#    (('_ste', 305),
#     [(('_ster', 51), [(('_stere', 20), [(('_stereo', 19), [])])]),
#      (('_step', 44), []),
#      (('_stee', 40), [(('_steel', 17), [])]),
#      (('_stea', 39), []),
#      (('_stei', 24), [(('_stein', 22), [])]),
#      (('_sten', 24), [])]),
#    (('_sto', 244),
#     [(('_stor', 66), []),
#      (('_stoc', 37), [(('_stock', 36), [])]),
#      (('_ston', 27), [(('_stone', 21), [])])]),
#    (('_sti', 130), [(('_stil', 21), []), (('_stin', 20), [])]),
#    (('_stu', 111), [(('_stud', 23), []), (('_stur', 19), [])]),
#    (('_sty', 29), [(('_styl', 19), [])])]),
#  (('ly_', 1698),
#   [(('lly_', 574),
#     [(('ally_', 432),
#       [(('cally_', 204),
#         [(('ically_', 198),
#           [(('tically_', 74), []),
#            (('gically_', 25), []),
#            (('rically_', 21), []),
#            (('nically_', 17), [])])]),
#        (('nally_', 61), [(('onally_', 43), [(('ionally_', 38), [])])]),
#        (('ially_', 46), []),
#        (('ually_', 33), []),
#        (('rally_', 29), []),
#        (('tally_', 21), [])]),
#      (('ully_', 58), [(('fully_', 50), [])]),
#      (('illy_', 39), []),
#      (('elly_', 27), []),
#      (('olly_', 18), [])]),
#    (('ely_', 257),
#     [(('vely_', 102),
#       [(('ively_', 99),
#         [(('tively_', 68), [(('atively_', 29), []), (('ctively_', 21), [])]),
#          (('sively_', 27), [])])]),
#      (('tely_', 56), [(('ately_', 40), [])]),
#      (('sely_', 22), [])]),
#    (('tly_', 166),
#     [(('ntly_', 93), [(('ently_', 61), []), (('antly_', 27), [])]),
#      (('stly_', 19), [])]),
#    (('sly_', 127),
#     [(('usly_', 100), [(('ously_', 99), [(('iously_', 41), [])])]),
#      (('ssly_', 24), [(('essly_', 23), [(('lessly_', 21), [])])])]),
#    (('bly_', 110),
#     [(('ably_', 76), [(('rably_', 19), [])]), (('ibly_', 19), [])]),
#    (('dly_', 86), [(('edly_', 30), [])]),
#    (('rly_', 72), [(('erly_', 36), []), (('arly_', 23), [])]),
#    (('gly_', 67), [(('ngly_', 62), [(('ingly_', 59), [])])]),
#    (('ily_', 64), [(('rily_', 27), [(('arily_', 20), [])])]),
#    (('nly_', 29), []),
#    (('hly_', 24), []),
#    (('fly_', 21), []),
#    (('aly_', 18), []),
#    (('oly_', 17), []),
#    (('ply_', 17), [])]),
#  (('en_', 1674),
#   [(('den_', 237),
#     [(('rden_', 36), [(('arden_', 17), [])]),
#      (('nden_', 28), []),
#      (('dden_', 27), []),
#      (('lden_', 26), []),
#      (('aden_', 21), [])]),
#    (('sen_', 191),
#     [(('ssen_', 36), []),
#      (('nsen_', 26), []),
#      (('usen_', 24), [(('ausen_', 20), [(('hausen_', 19), [])])])]),
#    (('men_', 187),
#     [(('emen_', 31), []),
#      (('smen_', 29), []),
#      (('rmen_', 19), []),
#      (('amen_', 18), [])]),
#    (('ten_', 136),
#     [(('tten_', 38), [(('itten_', 17), [])]), (('sten_', 25), [])]),
#    (('gen_', 120),
#     [(('ngen_', 42), [(('ingen_', 34), [])]), (('ogen_', 24), [])]),
#    (('een_', 95), [(('reen_', 23), []), (('teen_', 17), [])]),
#    (('len_', 87), [(('llen_', 38), [])]),
#    (('ren_', 80), []),
#    (('ken_', 80), []),
#    (('ven_', 76), [(('aven_', 27), [])]),
#    (('hen_', 67), [(('chen_', 32), [])]),
#    (('ien_', 66), []),
#    (('nen_', 43), []),
#    (('pen_', 35), []),
#    (('zen_', 33), []),
#    (('ben_', 25), []),
#    (('wen_', 24), []),
#    (('uen_', 21), []),
#    (('fen_', 20), [])]),
#  (('_sa', 1672),
#   [(('_san', 292),
#     [(('_sand', 96), []),
#      (('_sant', 42), []),
#      (('_sang', 36), []),
#      (('_sanc', 23), [(('_sanct', 17), [])])]),
#    (('_sal', 237),
#     [(('_sala', 44), []),
#      (('_salt', 30), []),
#      (('_sali', 30), []),
#      (('_salv', 26), []),
#      (('_sale', 19), []),
#      (('_salo', 18), [])]),
#    (('_sar', 161), [(('_sara', 46), [])]),
#    (('_sam', 143), [(('_sama', 33), []), (('_samp', 20), [])]),
#    (('_sat', 106), [(('_sati', 28), [])]),
#    (('_sab', 71), [(('_saba', 18), [])]),
# ...
#  (('_kh', 205),
#   [(('_kha', 103), [(('_khan', 21), []), (('_khal', 19), [])]),
#    (('_kho', 35), []),
#    (('_khu', 22), [])]),
#  (('go_', 202),
#   [(('ngo_', 61), [(('ango_', 23), []), (('ingo_', 17), [])]),
#    (('ago_', 40), []),
#    (('igo_', 32), []),
#    (('ego_', 22), [])]),
#  (('_za', 200),
#   [(('_zam', 26), []),
#    (('_zan', 25), []),
#    (('_zar', 22), []),
#    (('_zap', 19), [])]),
#  (('gy_', 200),
#   [(('ogy_', 146),
#     [(('logy_', 144),
#       [(('ology_', 138),
#         [(('tology_', 24), []),
#          (('iology_', 23), []),
#          (('nology_', 19), [])])])])]),
#  (('ak_', 197), [(('eak_', 26), []), (('rak_', 22), []), (('hak_', 18), [])]),
#  (('ip_', 196),
#   [(('hip_', 122),
#     [(('ship_', 118),
#       [(('rship_', 46), [(('ership_', 21), []), (('orship_', 20), [])]),
#        (('nship_', 31), [(('anship_', 19), [])])])]),
#    (('lip_', 18), [])]),
#  (('_yo', 196),
#   [(('_you', 41), []),
#    (('_yos', 39), [(('_yosh', 32), [(('_yoshi', 32), [])])]),
#    (('_yor', 24), []),
#    (('_yon', 18), [])]),
#  (('wn_', 195),
#   [(('own_', 168),
#     [(('town_', 102), [(('stown_', 36), [])]), (('down_', 36), [])]),
#    (('awn_', 23), [])]),
#  (('un_', 190),
#   [(('run_', 22), []),
#    (('oun_', 19), []),
#    (('gun_', 18), []),
#    (('sun_', 18), []),
#    (('hun_', 17), [])]),
#  (('rk_', 189),
#   [(('ark_', 79), [(('mark_', 32), [])]),
#    (('ork_', 68), [(('work_', 49), [])]),
#    (('irk_', 21), [])]),
#  (('cy_', 184),
#   [(('ncy_', 96), [(('ency_', 55), []), (('ancy_', 34), [])]),
#    (('acy_', 56), [(('racy_', 20), [])])]),
#  (('_ev', 184),
#   [(('_eva', 67),
#     [(('_evan', 27),
#       [(('_evang', 19), [(('_evange', 19), [(('_evangel', 19), [])])])])]),
#    (('_eve', 61), [(('_ever', 34), []), (('_even', 17), [])]),
#    (('_evi', 23), []),
#    (('_evo', 20), [])]),
#  (('tz_', 182),
#   [(('itz_', 72), [(('witz_', 19), [])]),
#    (('etz_', 22), []),
#    (('ntz_', 21), []),
#    (('rtz_', 18), []),
#    (('atz_', 17), [])]),
#  (('wa_', 181), [(('awa_', 90), [(('kawa_', 25), [])])]),
#  (('si_', 181), [(('ssi_', 36), []), (('asi_', 33), []), (('osi_', 18), [])]),
#  (('_os', 178),
#   [(('_ost', 51), [(('_oste', 21), []), (('_ostr', 21), [])]),
#    (('_osc', 19), []),
#    (('_oss', 18), [])]),
#  (('_ir', 178),
#   [(('_irr', 56), [(('_irre', 30), [])]),
#    (('_iro', 36), [(('_iron', 31), [])]),
#    (('_iri', 23), []),
#    (('_ira', 17), [])]),
#  (('_sm', 177),
#   [(('_sma', 46), []),
#    (('_smo', 45), []),
#    (('_smi', 36), [(('_smit', 23), [(('_smith', 17), [])])]),
#    (('_sme', 26), [])]),
#  (('_ol', 177),
#   [(('_oli', 44), [(('_oliv', 18), [])]),
#    (('_ole', 23), []),
#    (('_old', 20), [])]),
#  (('ff_', 177),
#   [(('off_', 60), []),
#    (('iff_', 41), []),
#    (('uff_', 25), []),
#    (('aff_', 24), [])]),
#  (('ok_', 176),
#   [(('ook_', 104),
#     [(('rook_', 35), [(('brook_', 33), [])]), (('book_', 35), [])])]),
#  (('_ed', 173),
#   [(('_edi', 46), [(('_edit', 20), [])]),
#    (('_edg', 23), []),
#    (('_edu', 21), [])]),
#  (('by_', 172),
#   [(('sby_', 29), []),
#    (('bby_', 25), []),
#    (('lby_', 18), []),
#    (('rby_', 18), [])]),
#  (('_av', 172),
#   [(('_ave', 56), [(('_aver', 19), [])]),
#    (('_avi', 37), []),
#    (('_ava', 27), []),
#    (('_avo', 24), [])]),
#  (('_af', 171),
#   [(('_aff', 63), [(('_affi', 24), [])]),
#    (('_afr', 30), [(('_afri', 17), [])]),
#    (('_aft', 24), [(('_afte', 19), [(('_after', 18), [])])])]),
#  (('_sn', 168),
#   [(('_sno', 67), [(('_snow', 39), [])]),
#    (('_sna', 42), []),
#    (('_sne', 29), []),
#    (('_sni', 17), [])]),
#  (('pa_', 168), [(('apa_', 28), []), (('ppa_', 21), [])]),
#  (('hs_', 167),
#   [(('ths_', 68), []),
#    (('phs_', 31), []),
#    (('chs_', 26), []),
#    (('ghs_', 18), [])]),
#  (('em_', 166),
#   [(('lem_', 26), []),
#    (('eem_', 22), []),
#    (('hem_', 21), []),
#    (('tem_', 20), []),
#    (('rem_', 17), [])]),
#  (('_ea', 166),
#   [(('_ear', 65), [(('_eart', 19), [(('_earth', 19), [])])]),
#    (('_eas', 53), [(('_east', 34), [])])]),
#  (('be_', 163),
#   [(('mbe_', 36), [(('ombe_', 29), [(('combe_', 23), [])])]),
#    (('abe_', 23), []),
#    (('ibe_', 21), []),
#    (('ube_', 20), []),
#    (('obe_', 20), [])]),
#  (('_eu', 161), [(('_eur', 58), [(('_euro', 43), [])]), (('_eup', 17), [])]),
#  (('_cy', 159),
#   [(('_cyc', 42), [(('_cycl', 38), [(('_cyclo', 19), [])])]),
#    (('_cyt', 19), [(('_cyto', 18), [])]),
#    (('_cyb', 18), [])]),
#  (('ik_', 157), [(('nik_', 39), []), (('rik_', 19), [])]),
#  (('ac_', 156), [(('iac_', 22), []), (('nac_', 21), [])]),
#  (('nk_', 156),
#   [(('ank_', 64), [(('bank_', 32), [])]),
#    (('ink_', 53), [(('link_', 22), [])]),
#    (('unk_', 25), [])]),
#  (('ct_', 153),
#   [(('ect_', 61), []),
#    (('act_', 36), []),
#    (('ict_', 23), []),
#    (('uct_', 20), [])]),
#  (('_ec', 151), [(('_eco', 34), []), (('_ecc', 24), []), (('_ech', 21), [])]),
#  (('_ep', 150), [(('_epi', 81), [(('_epis', 17), [])])]),
#  (('mo_', 150), [(('amo_', 32), []), (('omo_', 30), []), (('imo_', 25), [])]),
#  (('op_', 145),
#   [(('oop_', 27), []),
#    (('top_', 23), []),
#    (('rop_', 22), []),
#    (('lop_', 17), [])]),
#  (('_ly', 144), [(('_lyn', 34), []), (('_lyc', 17), []), (('_lys', 17), [])]),
#  (('so_', 142), [(('sso_', 30), []), (('oso_', 22), [])]),
#  (('_us', 141), [(('_usa', 25), [])]),
#  (('lt_', 141),
#   [(('ult_', 51), [(('ault_', 33), [])]),
#    (('elt_', 28), []),
#    (('alt_', 22), []),
#    (('ilt_', 20), []),
#    (('olt_', 18), [])]),
#  (('_ze', 140), [(('_zen', 20), [])]),
#  (('ez_', 138), [(('rez_', 22), []), (('dez_', 19), []), (('uez_', 17), [])]),
#  (('_il', 138), [(('_ill', 61), [(('_illu', 26), [(('_illus', 17), [])])])]),
#  (('za_', 137), [(('nza_', 40), [(('anza_', 23), [])]), (('aza_', 21), [])]),
#  (('ft_', 137),
#   [(('aft_', 53),
#     [(('raft_', 30), [(('craft_', 21), [])]), (('haft_', 18), [])]),
#    (('oft_', 32), [(('roft_', 18), [(('croft_', 17), [])])]),
#    (('ift_', 31), [])]),
#  (('_ur', 136), [(('_uri', 23), []), (('_urb', 21), []), (('_ura', 17), [])]),
#  (('_ye', 136), [(('_yel', 25), [(('_yell', 19), [])]), (('_yea', 24), [])]),
#  (('ws_', 135),
#   [(('ows_', 71),
#     [(('lows_', 29), [(('llows_', 17), [])]), (('rows_', 17), [])]),
#    (('ews_', 38), []),
#    (('aws_', 22), [])]),
#  (('_bh', 135), [(('_bha', 90), [(('_bhar', 18), [])]), (('_bhu', 17), [])]),
#  (('_oc', 135),
#   [(('_occ', 47), [(('_occu', 24), [])]),
#    (('_oct', 27), []),
#    (('_oce', 18), [])]),
#  (('_up', 133), [(('_ups', 23), [])]),
#  (('_et', 132), [(('_eth', 58), [(('_ethn', 27), [(('_ethno', 20), [])])])]),
#  (('ek_', 131), [(('eek_', 27), [])]),
#  (('_ji', 130), [(('_jin', 36), []), (('_jia', 23), [])]),
#  (('_my', 126), [(('_mys', 22), []), (('_myc', 19), [])]),
#  (('aw_', 125), [(('haw_', 28), [(('shaw_', 22), [])]), (('law_', 24), [])]),
#  (('_ak', 124), [(('_aka', 24), []), (('_aki', 23), [])]),
#  (('ja_', 122), [(('aja_', 26), []), (('ija_', 21), []), (('nja_', 20), [])]),
#  (('_kn', 121), [(('_kno', 49), []), (('_kni', 27), []), (('_kne', 18), [])]),
#  (('ou_', 119), [(('hou_', 38), [(('zhou_', 29), [])])]),
#  (('oy_', 117), [(('roy_', 25), []), (('boy_', 19), [])]),
#  (('ew_', 116), [(('iew_', 32), [(('view_', 29), [])]), (('rew_', 26), [])]),
#  (('_ty', 116), [(('_typ', 39), []), (('_tyr', 30), [])]),
#  (('ev_', 116), [(('yev_', 21), [])]),
#  (('_yu', 116), []),
#  (('ei_', 115), [(('sei_', 21), [])]),
#  (('_wr', 114),
#   [(('_wre', 35), []),
#    (('_wra', 30), []),
#    (('_wri', 27), []),
#    (('_wro', 18), [])]),
#  (('bo_', 113), [(('mbo_', 35), []), (('obo_', 17), [])]),
#  (('yn_', 113), [(('lyn_', 36), []), (('wyn_', 17), [])]),
#  (('bs_', 112), [(('abs_', 19), []), (('mbs_', 18), []), (('ubs_', 18), [])]),
#  (('up_', 111), [(('oup_', 25), [(('roup_', 19), [])])]),
#  (('ua_', 110), [(('gua_', 19), []), (('hua_', 19), []), (('qua_', 18), [])]),
#  (('_ic', 110), [(('_ice', 22), []), (('_ico', 17), []), (('_ich', 17), [])]),
#  (('_ei', 109), [(('_eig', 22), []), (('_ein', 21), [])]),
#  (('sk_', 109), []),
#  (('_ps', 109),
#   [(('_psy', 59),
#     [(('_psyc', 55), [(('_psych', 55), [(('_psycho', 42), [])])])]),
#    (('_pse', 18), [])]),
#  (('ru_', 108), [(('aru_', 33), []), (('uru_', 25), [])]),
#  (('_rh', 108),
#   [(('_rho', 28), []),
#    (('_rhe', 26), []),
#    (('_rhi', 24), []),
#    (('_rhy', 17), [])]),
#  (('_id', 106), [(('_ide', 42), [])]),
#  (('ix_', 106), [(('rix_', 26), [])]),
#  (('ap_', 105), []),
#  (('ab_', 104), []),
#  (('rm_', 103),
#   [(('orm_', 54), [(('form_', 27), [])]),
#    (('arm_', 23), []),
#    (('erm_', 17), [])]),
#  (('gi_', 103), [(('ngi_', 23), []), (('agi_', 23), [])]),
#  (('ao_', 102), []),
#  (('fe_', 102),
#   [(('ffe_', 41),
#     [(('iffe_', 23), [(('liffe_', 22), [(('cliffe_', 17), [])])])]),
#    (('ife_', 31), [])]),
#  (('my_', 102), [(('amy_', 25), []), (('mmy_', 24), []), (('omy_', 24), [])]),
#  (('sy_', 102), [(('ssy_', 34), [])]),
#  (('_ae', 102), [(('_aer', 44), [(('_aero', 34), [])])]),
#  (('ji_', 102), [(('nji_', 21), []), (('aji_', 19), []), (('iji_', 17), [])]),
#  (('_on', 99), []),
#  (('ud_', 99), [(('aud_', 27), []), (('oud_', 24), [])]),
#  (('su_', 98), [(('tsu_', 43), [(('atsu_', 20), [])])]),
#  (('ho_', 97), [(('cho_', 29), [])]),
#  (('_zi', 96), [(('_zin', 20), [])]),
#  (('bi_', 95), [(('abi_', 28), [])]),
#  (('ux_', 95), [(('aux_', 41), [(('eaux_', 22), [])]), (('eux_', 20), [])]),
#  (('_ul', 93), [(('_ult', 26), [(('_ultr', 18), [(('_ultra', 17), [])])])]),
#  (('_zo', 93), [(('_zoo', 21), [])]),
#  (('ex_', 93), [(('lex_', 30), [])]),
#  (('ón_', 92), [(('ión_', 41), [(('ción_', 30), [(('ación_', 20), [])])])]),
#  (('_of', 92),
#   [(('_off', 70),
#     [(('_offe', 22), []), (('_offi', 20), [(('_offic', 19), [])])])]),
#  (('_kl', 91), [(('_kla', 24), []), (('_kle', 22), []), (('_kli', 20), [])]),
#  (('oe_', 91), [(('hoe_', 20), [])]),
#  (('ci_', 91), [(('cci_', 24), [])]),
#  (('ye_', 89), [(('aye_', 24), [])]),
#  (('_gh', 89), [(('_gha', 40), []), (('_gho', 22), [])]),
#  (('py_', 88), [(('ppy_', 24), []), (('opy_', 19), [])]),
#  (('ig_', 87), []),
#  (('eo_', 86), []),
#  (('ag_', 85), []),
#  (('po_', 85), []),
#  (('_od', 84), [(('_odo', 18), []), (('_ode', 17), [])]),
#  (('uk_', 83), []),
#  (('vo_', 83), [(('ovo_', 21), [])]),
#  (('hu_', 82), []),
#  (('dt_', 82),
#   [(('adt_', 22), [(('tadt_', 19), [(('stadt_', 19), [])])]),
#    (('rdt_', 21), [(('ardt_', 21), [(('hardt_', 19), [])])])]),
#  (('ec_', 82), []),
#  (('vi_', 81), [(('avi_', 31), [])]),
#  (('ox_', 81), [(('box_', 29), [])]),
#  (('_it', 80), [(('_ita', 29), [(('_ital', 17), [])])]),
#  (('_ut', 80), []),
#  (('mp_', 80), [(('amp_', 37), []), (('ump_', 21), [])]),
#  (('zi_', 79), [(('zzi_', 21), []), (('azi_', 20), [])]),
#  (('_ot', 79), [(('_ott', 25), [])]),
#  (('_ts', 79), [(('_tsu', 32), []), (('_tsa', 18), [])]),
#  (('_az', 78), [(('_aza', 19), [])]),
#  (('_ay', 78), [(('_aya', 20), [])]),
#  (('_tw', 78), [(('_twi', 37), []), (('_twe', 28), [])]),
#  (('og_', 77), [(('log_', 18), [])]),
#  (('_py', 77), [(('_pyr', 32), [])]),
#  (('af_', 76), []),
#  (('_ah', 76), []),
#  (('ax_', 76), []),
#  (('ku_', 75), [(('aku_', 21), []), (('oku_', 17), [])]),
#  (('_dy', 74), [(('_dys', 22), []), (('_dyn', 22), [])]),
#  (('ep_', 74), [(('eep_', 26), [])]),
#  (('fa_', 74), []),
#  (('ii_', 74), []),
#  (('oo_', 74), []),
#  (('az_', 72), []),
#  (('av_', 72), [(('lav_', 34), [(('slav_', 27), [])])]),
#  (('_eq', 72),
#   [(('_equ', 71),
#     [(('_equi', 34), []), (('_equa', 30), [(('_equal', 19), [])])])]),
#  (('_om', 71), [(('_omn', 18), [(('_omni', 17), [])])]),
#  (('_eg', 71), [(('_egg', 18), [])]),
#  (('_aw', 71), [(('_awa', 35), [])]),
#  (('eh_', 69), []),
#  (('fy_', 69), [(('ify_', 45), []), (('ffy_', 17), [])]),
#  (('pi_', 69), []),
#  (('ef_', 69), []),
#  (('_aa', 69), []),
#  (('_by', 68), []),
#  (('fs_', 68), [(('ffs_', 32), [])]),
#  (('ui_', 67), []),
#  (('_eb', 67), [(('_ebe', 18), [])]),
#  (('oa_', 66), []),
#  (('_ny', 66), []),
#  (('_gy', 66), []),
#  (('aa_', 66), []),
#  (('_um', 65), [(('_umb', 17), [])]),
#  (('pt_', 65), [(('ept_', 19), [])]),
#  (('_dh', 64), [(('_dha', 33), [])]),
#  (('_ig', 64), [(('_ign', 30), [])]),
#  (('_ef', 63), [(('_eff', 38), [])]),
#  (('zo_', 61), [(('zzo_', 19), [])]),
#  (('ib_', 61), []),
#  (('_wy', 61), []),
#  (('ph_', 61), [(('aph_', 28), [(('raph_', 24), [(('graph_', 23), [])])])]),
#  (('lk_', 61), [(('alk_', 31), [])]),
#  (('bu_', 60), []),
#  (('_sq', 60), [(('_squ', 59), [(('_squa', 35), [])])]),
#  (('oc_', 60), []),
#  (('_ok', 60), [(('_oka', 17), [])]),
#  (('du_', 60), []),
#  (('_ry', 59), []),
#  (('yl_', 59), []),
#  (('if_', 59), []),
#  (('tu_', 59), []),
#  (('_io', 58), [(('_ion', 20), [])]),
#  (('_qa', 58), []),
#  (('pp_', 57), [(('app_', 21), [])]),
#  (('ub_', 57), []),
#  (('yo_', 57), [(('ayo_', 21), [])]),
#  (('iz_', 56), []),
#  (('án_', 56), []),
#  (('_ib', 56), []),
#  (('nu_', 56), [(('anu_', 19), [])]),
#  (('_zu', 55), []),
#  (('_zh', 55), []),
#  (('of_', 55), [(('oof_', 18), [])]),
#  (('eg_', 54), []),
#  (('_oa', 53), [(('_oak', 25), [])]),
#  (('lu_', 53), [(('ulu_', 17), [])]),
#  (('aj_', 52), [(('raj_', 28), [])]),
#  (('lf_', 52), []),
#  (('_xi', 51), [(('_xia', 21), [])]),
#  (('_ky', 51), []),
#  (('lm_', 50), []),
#  (('_ox', 50), [(('_oxi', 18), [(('_oxid', 17), [])])]),
#  (('_iv', 49), []),
#  (('nz_', 49), [(('enz_', 20), []), (('anz_', 17), [])]),
#  (('jo_', 49), []),
#  (('_ip', 48), []),
#  (('hr_', 48), []),
#  (('we_', 47), []),
#  (('hn_', 47), [(('ahn_', 24), [])]),
#  (('oi_', 46), []),
#  (('mu_', 46), []),
#  (('eu_', 46), [(('ieu_', 19), [])]),
#  (('gg_', 46), []),
#  (('rf_', 44), [(('orf_', 25), [(('dorf_', 22), [])])]),
#  (('fi_', 44), []),
#  (('_ey', 44), [(('_eye', 26), [])]),
#  (('_aq', 43), [(('_aqu', 33), [(('_aqua', 17), [])])]),
#  (('_sv', 43), [(('_sve', 28), [])]),
#  (('_og', 42), []),
#  (('_wu', 42), []),
#  (('_yi', 42), []),
#  (('je_', 42), []),
#  (('cu_', 42), [(('scu_', 23), [(('escu_', 21), [])])]),
#  (('eb_', 42), []),
#  (('dd_', 41), []),
#  (('rr_', 41), [(('arr_', 17), [])]),
#  (('_ll', 40), [(('_lla', 24), [(('_llan', 22), [])])]),
#  (('ug_', 39), []),
#  (('ée_', 38), []),
#  (('ob_', 38), []),
#  (('hl_', 38), []),
#  (('_ia', 38), []),
#  (('_sr', 38), [(('_sri', 19), [])]),
#  (('iu_', 37), []),
#  (('rp_', 37), [(('arp_', 18), [])]),
#  (('mb_', 37), [(('omb_', 19), [])]),
#  (('_mé', 36), []),
#  (('_ax', 36), []),
#  (('_vu', 36), [(('_vul', 22), [])]),
#  (('oh_', 36), []),
#  (('_uc', 36), []),
#  (('rl_', 36), []),
#  (('_vl', 35), [(('_vla', 24), [])]),
#  (('gu_', 34), []),
#  (('_if', 34), []),
#  (('_ow', 34), []),
#  (('yu_', 34), []),
#  (('zy_', 33), []),
#  (('rc_', 33), []),
#  (('_oh', 33), []),
#  (('wi_', 33), []),
#  (('mm_', 33), []),
#  (('yi_', 33), []),
#  (('té_', 32), []),
#  (('_ao', 32), []),
#  (('_oo', 31), []),
#  (('uo_', 31), []),
#  (('iv_', 31), []),
#  (('kh_', 31), []),
#  (('_ud', 31), []),
#  (('vy_', 31), []),
#  (('ów_', 31), []),
#  (('rb_', 31), []),
#  (('_gw', 30), []),
#  (('_ng', 30), []),
#  (('_oi', 30), []),
#  (('_sz', 30), []),
#  (('_pt', 30), []),
#  (('_aj', 30), []),
#  (('_dw', 30), []),
#  (('_kw', 29), []),
#  (('sc_', 29), []),
#  (('_ee', 28), []),
#  (('pu_', 28), []),
#  (('ju_', 28), []),
#  (('_iz', 27), []),
#  (('ré_', 27), []),
#  (('sz_', 27), []),
#  (('aq_', 27), []),
#  (('wl_', 27), []),
#  (('_ii', 27), []),
#  (('_ik', 26), []),
#  (('fo_', 26), []),
#  (('_oe', 26), []),
#  (('uf_', 26), []),
#  (('_qi', 26), []),
#  (('_ub', 26), []),
#  (('és_', 26), []),
#  (('_gn', 25), []),
#  (('_ek', 25), []),
#  (('oz_', 25), []),
#  (('uc_', 25), []),
#  (('gn_', 25), [(('ign_', 21), [])]),
#  (('ym_', 25), [(('nym_', 17), [(('onym_', 17), [])])]),
#  (('bb_', 25), []),
#  (('yr_', 25), []),
#  (('nh_', 25), []),
#  (('_iw', 24), []),
#  (('yd_', 24), []),
#  (('_ré', 23), []),
#  (('_xe', 23), []),
#  (('uz_', 23), []),
#  (('_ug', 23), []),
#  (('xi_', 22), []),
#  (('nj_', 22), [(('anj_', 19), [])]),
#  (('rh_', 22), [(('arh_', 19), [(('garh_', 18), [])])]),
#  (('_eo', 22), []),
#  (('_eh', 22), []),
#  (('hm_', 22), []),
#  (('zu_', 22), []),
#  (('dh_', 21), []),
#  (('_nc', 21), []),
#  (('uy_', 21), []),
#  (('sp_', 20), []),
#  (('nc_', 20), []),
#  (('_ew', 20), []),
#  (('xy_', 20), []),
#  (('_ih', 20), []),
#  (('_vr', 19), []),
#  (('fu_', 19), []),
#  (('_hs', 19), []),
#  (('tv_', 19), []),
#  (('ih_', 19), []),
#  (('_ua', 18), []),
#  (('cc_', 18), []),
#  (('_ue', 18), []),
#  (('_hr', 18), []),
#  (('_cs', 18), []),
#  (('_xa', 18), []),
#  (('sl_', 17), []),
#  (('_ie', 17), []),
#  (('pf_', 17), []),
#  (('_uk', 17), []),
#  (('_ej', 17), []),
#  (('rz_', 17), []),
#  (('_xx', 17), [])]

# %%
pre = []
suf = []

for y in [x[0] for x in asplit]:
    if y[0][0] == '_':
        pre.append((y[0], y[1] / lcount[y[0].replace('_', '')]))
    else:
        suf.append((y[0], y[1] / lcount[y[0].replace('_', '')]))

# %%
suf
# Out:
# [('s_', 0.32148905575970604),
#  ('e_', 0.15124313995600686),
#  ('n_', 0.184460592509782),
#  ('a_', 0.11057150669948045),
#  ('d_', 0.26809184481393505),
#  ('r_', 0.1090950432014552),
#  ('y_', 0.4768531088786315),
#  ('g_', 0.2471687786805877),
#  ('t_', 0.10782437429160706),
#  ('l_', 0.09612861575626315),
#  ('i_', 0.06190810967288367),
#  ('o_', 0.07527788292783646),
#  ('m_', 0.09136845019727279),
#  ('h_', 0.09567094648335417),
#  ('k_', 0.13970639881997612),
#  ('c_', 0.055857163594135575),
#  ('u_', 0.04553221429289376),
#  ('p_', 0.040223214285714286),
#  ('f_', 0.05682417003337432),
#  ('z_', 0.13584667228306654),
#  ('w_', 0.05964170468454434),
#  ('x_', 0.20748576078112285),
#  ('v_', 0.04694527736131934),
#  ('b_', 0.02344641560327835),
#  ('é_', 0.23108108108108108),
#  ('j_', 0.03794266441821248),
#  ('q_', 0.046357615894039736),
#  ('á_', 0.1151685393258427)]

# %%
pre
# Out:
# [('_s', 0.19317782393353572),
#  ('_c', 0.2876179416461025),
#  ('_m', 0.29033709420640963),
#  ('_p', 0.3505357142857143),
#  ('_a', 0.08579710144927537),
#  ('_b', 0.40247951032264756),
#  ('_r', 0.09098074882522358),
#  ('_t', 0.11070439807502927),
#  ('_d', 0.1879968329374505),
#  ('_h', 0.1876680680225732),
#  ('_g', 0.18932345387950997),
#  ('_l', 0.0927757762552323),
#  ('_e', 0.047548159175239406),
#  ('_f', 0.3726506235728087),
#  ('_k', 0.2592540563320924),
#  ('_i', 0.050563114290834404),
#  ('_n', 0.04931370722315384),
#  ('_w', 0.33626349171024816),
#  ('_o', 0.04587219105956846),
#  ('_v', 0.21270614692653672),
#  ('_u', 0.0676449894461755),
#  ('_j', 0.4654300168634064),
#  ('_y', 0.055050230790116755),
#  ('_z', 0.14806234203875315),
#  ('_q', 0.32691149909692957),
#  ('_x', 0.06509357200976404),
#  ('_é', 0.07162162162162163),
#  ('_á', 0.0702247191011236)]
